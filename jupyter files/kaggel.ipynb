# %%
pip install --upgrade pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 26.1 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.0
#     Uninstalling pip-24.0:
#       Successfully uninstalled pip-24.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
ls

# %%
# !git clone https://github.com/mathLab/PyGeM
# Out:
# Cloning into 'PyGeM'...
# remote: Enumerating objects: 3959, done.
# remote: Counting objects: 100% (484/484), done.
# remote: Compressing objects: 100% (226/226), done.
# remote: Total 3959 (delta 291), reused 424 (delta 251), pack-reused 3475 (from 1)
# Receiving objects: 100% (3959/3959), 26.06 MiB | 30.05 MiB/s, done.
# Resolving deltas: 100% (2429/2429), done.

# %%
cd PyGeM
# Out:
# /kaggle/working/PyGeM

# %%
# !pip install -e
# Out:
# Usage:
#   pip install [options] <requirement specifier> [package-index-options] ...
#   pip install [options] -r <requirements file> [package-index-options] ...
#   pip install [options] [-e] <vcs project url> ...
#   pip install [options] [-e] <local project path> ...
#   pip install [options] <archive url/path> ...
#
# -e option requires 1 argument

# %%
pip install .
# Out:
# Processing /kaggle/working/PyGeM
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pygem: filename=pygem-2.0.0-py3-none-any.whl size=5865709 sha256=3ea22e7508ad6666836cfc0068dc3ede42b8c19a60c92f93481af076c7d9ece9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rcglgr0a/wheels/1c/22/08/3e6e20eb802b3d2bf441967b51a65e29a741dd11c3f9295b69
# Successfully built pygem
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pygem import RBF,ffd

# %%
ls
# Out:
# CITATION.cff  build/              docs/            readme/   tests/
# LICENSE.rst   code_formatter.sh*  pygem/           setup.py  tutorials/
# README.md     dockerfiles/        pygem.egg-info/  test.py

# %%
cd ..
# Out:
# /kaggle/working

# %%
# !git clone --branch kaggle https://github.com/shining0611armor/MATE.git
# Out:
# Cloning into 'MATE'...
# remote: Enumerating objects: 254, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 254 (delta 25), reused 0 (delta 0), pack-reused 199 (from 1)
# Receiving objects: 100% (254/254), 349.83 KiB | 8.97 MiB/s, done.
# Resolving deltas: 100% (88/88), done.

# %%
cd MATE
# Out:
# /kaggle/working/MATE

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.7/399.7 MB 80.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 51.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 128.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 77.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.9
#     Uninstalling widgetsnbextension-3.6.9:
#       Successfully uninstalled widgetsnbextension-3.6.9
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab_widgets 3.0.11
#     Uninstalling jupyterlab_widgets-3.0.11:
#       Successfully uninstalled jupyterlab_widgets-3.0.11
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.9
#     Uninstalling timm-1.0.9:
#       Successfully uninstalled timm-1.0.9
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
# ...

# %%
cd ./extensions/chamfer_dist
# Out:
# /kaggle/working/MATE/extensions/chamfer_dist

# %%
ls
# Out:
# __init__.py  chamfer.cu  chamfer_cuda.cpp  setup.py  test.py

# %%
pip install .
# Out:
# Processing /kaggle/working/MATE/extensions/chamfer_dist
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for chamfer: filename=chamfer-2.0.0-cp310-cp310-linux_x86_64.whl size=263230 sha256=1f4ece70ba6a325fb56035aa65e3184cb1cfb77432f7de5f146a3cee718b1d9e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a3fdre65/wheels/d1/11/db/f7f608a8a8afd13b85bada7e6b097a768e08c5aa9a9bb5b1fe
# Successfully built chamfer
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
cd ..
# Out:
# /kaggle/working/MATE/extensions

# %%
cd ..
# Out:
# /kaggle/working/MATE

# %%
cd ./extensions/emd
# Out:
# /kaggle/working/MATE/extensions/emd

# %%
# !pip install "git+https://github.com/Crismorgan/Pointnet2_PyTorch.git#egg=pointnet2_ops&subdirectory=pointnet2_ops_lib"
# Out:
# ...
#   Cloning https://github.com/Crismorgan/Pointnet2_PyTorch.git to /tmp/pip-install-ezjr6r6s/pointnet2-ops_7188de447ce7426abab95b920975e0d7
#   Running command git clone --filter=blob:none --quiet https://github.com/Crismorgan/Pointnet2_PyTorch.git /tmp/pip-install-ezjr6r6s/pointnet2-ops_7188de447ce7426abab95b920975e0d7
#   Resolved https://github.com/Crismorgan/Pointnet2_PyTorch.git to commit dca6aa58d683edab0994cd4dfd523139f7a5ca72
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pointnet2_ops: filename=pointnet2_ops-3.0.0-cp310-cp310-linux_x86_64.whl size=199237 sha256=22978cfaeb9a3188be5f3fd312cd43110ebb00217b597b03897fa86c2a9bd858
#   Stored in directory: /tmp/pip-ephem-wheel-cache-72lyjcv_/wheels/51/5b/20/24dbffc0bc4888c103f6915455661380734468f2ed9f0e03e0
# Successfully built pointnet2_ops
# ...

# %%
cd /kaggle/working/MATE/extensions/emd
# Out:
# /kaggle/working/MATE/extensions/emd

# %%
# !pip install --upgrade https://github.com/unlimblue/KNN_CUDA/releases/download/0.2/KNN_CUDA-0.2-py3-none-any.whl

# %% [markdown]
# now we can download and unzip this dataset from this place

# %% [markdown]
# # modelnet40_c from link

# %% [markdown]
# here is the first way of downloading

# %%
ls
# Out:
# README.md    cuda/   gitignore.txt  test_emd_loss.py
# __init__.py  emd.py  setup.py

# %%
# Make sure the directory exists
# !mkdir -p /kaggle/working/MATE/modelnet40/

# Download the file using wget
# !wget -O /kaggle/working/MATE/modelnet40/filename.zip https://zenodo.org/api/records/6017834/files-archive

# Unzip the file into the same directory
# !unzip /kaggle/working/MATE/modelnet40/modelnet40_c.zip -d /content/MATE/modelnet40/
# Out:
# --2024-10-04 20:00:01--  https://zenodo.org/api/records/6017834/files-archive
# Resolving zenodo.org (zenodo.org)... 188.184.103.159, 188.184.98.238, 188.185.79.172, ...
# Connecting to zenodo.org (zenodo.org)|188.184.103.159|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: '/content/MATE/modelnet40/filename.zip'
#
#          /content/M     [ <=>                ]  48.73K   195KB/s               ^C
# unzip:  cannot find or open /content/MATE/modelnet40/modelnet40_c.zip, /content/MATE/modelnet40/modelnet40_c.zip.zip or /content/MATE/modelnet40/modelnet40_c.zip.ZIP.

# %%
# !wget -O /kaggle/working/MATE/modelnet40/filename.zip https://zenodo.org/api/records/6017834/files-archive

# %% [markdown]
# ### the second way is from drive and thats so fast

# %%
import gdown

# Make sure the directory exists
# !mkdir -p /kaggle/working/MATE/modelnet40/

# Use the file ID from the Google Drive link
file_id = "1-2lYA-Y44j7Bs4CzfPYzjh5xqAwACcZu"

# Download the file using gdown
gdown.download(f"https://drive.google.com/uc?id={file_id}", output="/kaggle/working/MATE/modelnet40/modelnet40_c.zip", quiet=False)

# !unzip -o /kaggle/working/MATE/modelnet40/modelnet40_c.zip -d /kaggle/working/MATE/modelnet40_c/
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1-2lYA-Y44j7Bs4CzfPYzjh5xqAwACcZu
# From (redirected): https://drive.google.com/uc?id=1-2lYA-Y44j7Bs4CzfPYzjh5xqAwACcZu&confirm=t&uuid=5f445e2d-8a9f-4281-9f29-097488ec27c4
# To: /kaggle/working/MATE/modelnet40/modelnet40_c.zip
# 100%|██████████| 1.97G/1.97G [00:13<00:00, 142MB/s]
# Archive:  /kaggle/working/MATE/modelnet40/modelnet40_c.zip
#  extracting: /kaggle/working/MATE/modelnet40_c/modelnet40_c.zip

# %%
ls
# Out:
# README.md    cuda/   gitignore.txt  test_emd_loss.py
# __init__.py  emd.py  setup.py

# %%
cd ..
# Out:
# /kaggle/working/MATE/extensions

# %%
cd ..
# Out:
# /kaggle/working/MATE

# %%
cd /kaggle/working/MATE/modelnet40_c/
# Out:
# /kaggle/working/MATE/modelnet40_c

# %%
ls
# Out:
# modelnet40_c.zip

# %%
# !unzip modelnet40_c.zip
# Out:
# Archive:  modelnet40_c.zip
#    creating: modelnet40_c/
#   inflating: modelnet40_c/data_uniform_1.npy
#   inflating: modelnet40_c/data_distortion_5.npy
#   inflating: modelnet40_c/data_occlusion_5.npy
#   inflating: modelnet40_c/data_occlusion_4.npy
#   inflating: modelnet40_c/data_distortion_4.npy
#   inflating: modelnet40_c/data_uniform_2.npy
#   inflating: modelnet40_c/data_density_4.npy
#   inflating: modelnet40_c/data_density_5.npy
#   inflating: modelnet40_c/data_uniform_3.npy
#   inflating: modelnet40_c/data_distortion_3.npy
#   inflating: modelnet40_c/.DS_Store
#   inflating: __MACOSX/modelnet40_c/._.DS_Store
#   inflating: modelnet40_c/data_density_1.npy
#   inflating: modelnet40_c/data_occlusion_3.npy
#   inflating: modelnet40_c/data_occlusion_2.npy
#   inflating: modelnet40_c/data_distortion_2.npy
#   inflating: modelnet40_c/data_uniform_4.npy
#   inflating: modelnet40_c/data_density_2.npy
#   inflating: modelnet40_c/data_occlusion_1.npy
# ...

# %% [markdown]
# # importing modelnet40 trained model

# %% [markdown]
# now i imported modelnet40 dataset

# %%
# !mkdir -p /kaggle/working/MATE/pretrained_models/

# !gdown https://drive.google.com/uc?id=1dZXEubRKBk0Oz44zMwuH4tTZ45qE0y_w -O /kaggle/working/MATE/pretrained_models/
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1dZXEubRKBk0Oz44zMwuH4tTZ45qE0y_w
# From (redirected): https://drive.google.com/uc?id=1dZXEubRKBk0Oz44zMwuH4tTZ45qE0y_w&confirm=t&uuid=921ad607-b81a-4bea-81c9-4359804bab70
# To: /kaggle/working/MATE/pretrained_models/modelnet_jt.pth
# 100%|████████████████████████████████████████| 352M/352M [00:08<00:00, 43.8MB/s]

# %%
cd /kaggle/working/MATE/
# Out:
# /kaggle/working/MATE

# %%
# !pip install ninja

# %%
# !ninja --version
# Out:
# 1.11.1.git.kitware.jobserver-1

# %% [markdown]
# For TTT training

# %%
# !CUDA_VISIBLE_DEVICES=0 python ttt.py --dataset_name modelnet --grad_steps 2 --config cfgs/tta/tta_modelnet.yaml --ckpts /kaggle/working/MATE/pretrained_models/modelnet_jt.pth
# Out:
# Streaming output truncated to the last 5000 lines.
#
# 2024-09-28 14:30:10,495 - Point_MAE - INFO - [Point_MAE]
#
# 2024-09-28 14:30:10,495 - Transformer - INFO - [args] {'mask_ratio': 0.9, 'mask_type': 'rand', 'trans_dim': 384, 'encoder_dims': 384, 'depth': 12, 'drop_path_rate': 0.1, 'num_heads': 6, 'decoder_depth': 4, 'decoder_num_heads': 6}
#
# 2024-09-28 14:30:10,920 - Point_MAE - INFO - [Point_MAE] divide point cloud into G64 x S32 points ...
#
# 2024-09-28 14:30:11,197 - Transformer - INFO - [Transformer] Successful Loading the ckpt from /content/MATE/pretrained_models/modelnet_jt.pth
#
# 2024-09-28 14:30:11,238 - tta_modelnet - INFO - Using Data parallel ...
#
# 2024-09-28 14:30:11,562 - tta_modelnet - INFO - [TEST - background], Sample - 1427 / 2468,GradStep - 0 / 2,Reconstruction Loss [52.098751068115234]
#
# 2024-09-28 14:30:11,882 - tta_modelnet - INFO - [TEST - background], Sample - 1427 / 2468,GradStep - 1 / 2,Reconstruction Loss [54.46198582649231]
#
# ...

# %% [markdown]
# ## TTT Online training

# %%
# !CUDA_VISIBLE_DEVICES=0 python ttt.py --dataset_name modelnet --online --grad_steps 1 --config cfgs/tta/tta_modelnet.yaml --ckpts /kaggle/working/MATE/pretrained_models/modelnet_jt.pth
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/utils/cpp_extension.py:1965: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Create experiment path successfully at ./experiments/tta_modelnet/tta/default
# Create TFBoard path successfully at ./experiments/tta_modelnet/tta/TFBoard/default
# 2024-10-04 20:53:45,045 - tta_modelnet - INFO - Copy the Config file from cfgs/tta/tta_modelnet.yaml to ./experiments/tta_modelnet/tta/default/config.yaml
# 2024-10-04 20:53:45,045 - tta_modelnet - INFO - args.mask_ratio : 0.9
# 2024-10-04 20:53:45,045 - tta_modelnet - INFO - args.alpha : 0.0
# 2024-10-04 20:53:45,045 - tta_modelnet - INFO - args.batch_size_tta : 48
# 2024-10-04 20:53:45,045 - tta_modelnet - INFO - args.stride_step : 1
# 2024-10-04 20:53:45,045 - tta_modelnet - INFO - args.batch_size : 1
# ...
